# %% [markdown]
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %%
import sympy
from sympy import *
import matplotlib.pyplot as plt
import numpy as np

# %%
x = sympy.symbols('x')

# %%
f = -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
# ans = sympy.solve(f)
# ans
#  Не решается

# %%
f, ff = sympy.symbols('f ff')

# %%
f = -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
ff = sympy.diff(f)
ff
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
# ans = sympy.solve(ff)
# ans
# Не решается

# %%
x = np.arange(0, 15.01, 0.01)

# %%
f = -12*x**4*np.sin(np.cos(x)) - 18*x**3+5*x**2 + 10*x - 30
plt.plot(x, f)
f2 = 0*x
plt.plot(x, f2)
plt.show()

# %% [markdown]
# Для графического решения задачи возьмем х в промежутке от 0 до 15.
# В указанном промежутке:
#     - Корни: 4, 8, 11, 14.
#     - Функция возрастает в интервале от 7 до 10 и от 13 до 15 (и далее)
#     - Функция убываетв интервале от 4 до 7 и от 10 до 13.
#     - Функция больше нуля при х > 8 и х < 11, а также при х > 14.
#     - Функция меньше нуля при x > 4 и x < 8, а также при x > 11 и x < 14.
